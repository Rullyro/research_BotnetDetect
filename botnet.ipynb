# %% [markdown]
# <a href="https://colab.research.google.com/github/KharismaMonika/Botnet_Detection/blob/rully/botnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import os
import pandas as pd
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# %% [markdown]
# # Read Dataset

# %%
init = pd.read_csv("C:\Punyaku\Rully\Botnet/init.csv")
init2 = pd.read_csv("C:\Punyaku\Rully\Botnet/init2.csv")
init3 = pd.read_csv("C:\Punyaku\Rully\Botnet/init3.csv")
init4 = pd.read_csv("C:\Punyaku\Rully\Botnet/init4.csv")
init5 = pd.read_csv("C:\Punyaku\Rully\Botnet/init5.csv")
dns1 = pd.read_csv("C:\Punyaku\Rully\Botnet/dns_application_2017_1.csv")
dns = pd.read_csv("C:\Punyaku\Rully\Botnet/dns_application_2017.csv")
appdns = pd.read_csv("C:\Punyaku\Rully\Botnet/applicationDNS.csv")
# Out:
# C:\Users\Rully Rosadi\AppData\Local\Temp\ipykernel_1900\2626145409.py:1: DtypeWarning: Columns (28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   init = pd.read_csv("C:\Punyaku\Rully\Botnet/init.csv")
# C:\Users\Rully Rosadi\AppData\Local\Temp\ipykernel_1900\2626145409.py:2: DtypeWarning: Columns (28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   init2 = pd.read_csv("C:\Punyaku\Rully\Botnet/init2.csv")
# C:\Users\Rully Rosadi\AppData\Local\Temp\ipykernel_1900\2626145409.py:6: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   dns1 = pd.read_csv("C:\Punyaku\Rully\Botnet/dns_application_2017_1.csv")

# %% [markdown]
# # Labelling

# %%
init['label'] = 'Botnet'
init2['label'] = 'Botnet'
init3['label'] = 'Botnet'
init4['label'] = 'Botnet'
init5['label'] = 'Botnet'
dns1['label'] = 'Normal'
dns['label'] = 'Normal'
appdns['label'] = 'Normal'

# %% [markdown]
# # Merging Dataframe

# %%
df = pd.concat([init,init2,init3,init4,init5,dns1,dns,appdns])
df.head()
# Out:
#   _path                           ts                 uid  \
# 0  conn  2017-04-25T00:01:24.221943Z  CcRRUf4FvYVy0WM1tf
# 1  conn  2017-04-25T00:01:05.437399Z  CskjGr1swnXFezlM0b
# 2  conn  2017-04-25T00:01:05.435065Z   CAnrobD8Gp6TJUHkc
# 3  conn  2017-04-25T00:01:05.361443Z  CP4uAC4tn9VWjhJWu7
# 4  conn   2017-04-25T00:01:05.36117Z  CmQVh52Dk2zV5D9hgj
#
#                    id.orig_h  id.orig_p          id.resp_h  id.resp_p proto  \
# 0              192.168.50.15      49204      192.168.50.88         53   udp
# 1   fe80::d58e:a29a:c48:dd8f        135  ff02::1:ff98:c06b        136  icmp
# 2  fe80::2c51:b7cc:8a98:c06b        135  ff02::1:ff48:dd8f        136  icmp
# 3              192.168.50.18      51400        224.0.0.252       5355   udp
# 4   fe80::d58e:a29a:c48:dd8f      63788          ff02::1:3       5355   udp
#
#   service duration  ...  geo.orig.city  geo.orig.latitude geo.orig.longitude  \
# 0     dns    206us  ...            NaN                NaN                NaN
# 1     NaN      NaN  ...            NaN                NaN                NaN
# 2     NaN      NaN  ...            NaN                NaN                NaN
# 3     dns      NaN  ...            NaN                NaN                NaN
# 4     dns      NaN  ...            NaN                NaN                NaN
#
#    geo.resp.country_code  geo.resp.region  geo.resp.city geo.resp.latitude  \
# 0                    NaN              NaN            NaN               NaN
# 1                    NaN              NaN            NaN               NaN
# 2                    NaN              NaN            NaN               NaN
# 3                    NaN              NaN            NaN               NaN
# 4                    NaN              NaN            NaN               NaN
#
#    geo.resp.longitude                    community_id   label
# 0                 NaN  1:o9DmB+Xdg3mjcpAWPAa4xMSQ8PA=  Botnet
# 1                 NaN  1:/3BVcTgZBvIwH3NdRMIuCTKDsco=  Botnet
# 2                 NaN  1:4pI7NSr1zcExpnwgrplWKhUeX2Y=  Botnet
# 3                 NaN  1:qmfbUmATO8xesLDLONvCq/Hw0hs=  Botnet
# 4                 NaN  1:1O9I3C6IMbR1/6T8NUA+v6rvntU=  Botnet
#
# [5 rows x 34 columns]

# %% [markdown]
# # DATA EXPLORATION

# %%
df.head()
# Out:
#   _path                           ts                 uid  \
# 0  conn  2017-04-25T00:01:24.221943Z  CcRRUf4FvYVy0WM1tf
# 1  conn  2017-04-25T00:01:05.437399Z  CskjGr1swnXFezlM0b
# 2  conn  2017-04-25T00:01:05.435065Z   CAnrobD8Gp6TJUHkc
# 3  conn  2017-04-25T00:01:05.361443Z  CP4uAC4tn9VWjhJWu7
# 4  conn   2017-04-25T00:01:05.36117Z  CmQVh52Dk2zV5D9hgj
#
#                    id.orig_h  id.orig_p          id.resp_h  id.resp_p proto  \
# 0              192.168.50.15      49204      192.168.50.88         53   udp
# 1   fe80::d58e:a29a:c48:dd8f        135  ff02::1:ff98:c06b        136  icmp
# 2  fe80::2c51:b7cc:8a98:c06b        135  ff02::1:ff48:dd8f        136  icmp
# 3              192.168.50.18      51400        224.0.0.252       5355   udp
# 4   fe80::d58e:a29a:c48:dd8f      63788          ff02::1:3       5355   udp
#
#   service duration  ...  geo.orig.city  geo.orig.latitude geo.orig.longitude  \
# 0     dns    206us  ...            NaN                NaN                NaN
# 1     NaN      NaN  ...            NaN                NaN                NaN
# 2     NaN      NaN  ...            NaN                NaN                NaN
# 3     dns      NaN  ...            NaN                NaN                NaN
# 4     dns      NaN  ...            NaN                NaN                NaN
#
#    geo.resp.country_code  geo.resp.region  geo.resp.city geo.resp.latitude  \
# 0                    NaN              NaN            NaN               NaN
# 1                    NaN              NaN            NaN               NaN
# 2                    NaN              NaN            NaN               NaN
# 3                    NaN              NaN            NaN               NaN
# 4                    NaN              NaN            NaN               NaN
#
#    geo.resp.longitude                    community_id   label
# 0                 NaN  1:o9DmB+Xdg3mjcpAWPAa4xMSQ8PA=  Botnet
# 1                 NaN  1:/3BVcTgZBvIwH3NdRMIuCTKDsco=  Botnet
# 2                 NaN  1:4pI7NSr1zcExpnwgrplWKhUeX2Y=  Botnet
# 3                 NaN  1:qmfbUmATO8xesLDLONvCq/Hw0hs=  Botnet
# 4                 NaN  1:1O9I3C6IMbR1/6T8NUA+v6rvntU=  Botnet
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2481757 entries, 0 to 298
# Data columns (total 34 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   _path                  object
#  1   ts                     object
#  2   uid                    object
#  3   id.orig_h              object
#  4   id.orig_p              int64
#  5   id.resp_h              object
#  6   id.resp_p              int64
#  7   proto                  object
#  8   service                object
#  9   duration               object
#  10  orig_bytes             float64
#  11  resp_bytes             float64
#  12  conn_state             object
#  13  local_orig             float64
#  14  local_resp             float64
#  15  missed_bytes           int64
#  16  history                object
#  17  orig_pkts              int64
#  18  orig_ip_bytes          int64
#  19  resp_pkts              int64
#  20  resp_ip_bytes          int64
#  21  tunnel_parents         float64
#  22  geo.orig.country_code  object
#  23  geo.orig.region        float64
#  24  geo.orig.city          float64
#  25  geo.orig.latitude      float64
#  26  geo.orig.longitude     float64
#  27  geo.resp.country_code  object
#  28  geo.resp.region        object
#  29  geo.resp.city          object
#  30  geo.resp.latitude      float64
#  31  geo.resp.longitude     float64
#  32  community_id           object
#  33  label                  object
# dtypes: float64(11), int64(7), object(16)
# memory usage: 662.7+ MB

# %%
df.describe()
# Out:
#           id.orig_p     id.resp_p    orig_bytes    resp_bytes  local_orig  \
# count  2.481757e+06  2.481757e+06  1.303034e+06  1.303034e+06         0.0
# mean   4.533909e+04  5.226163e+02  5.269900e+02  1.840320e+02         NaN
# std    1.819931e+04  1.400567e+03  2.272396e+05  1.393841e+04         NaN
# min    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00         NaN
# 25%    4.014400e+04  5.300000e+01  3.700000e+01  0.000000e+00         NaN
# 50%    5.122000e+04  5.300000e+01  5.800000e+01  3.700000e+01         NaN
# 75%    5.730800e+04  5.300000e+01  1.600000e+02  1.180000e+02         NaN
# max    6.553500e+04  1.750000e+04  1.674834e+08  2.697643e+06         NaN
#
#        local_resp  missed_bytes     orig_pkts  orig_ip_bytes     resp_pkts  \
# count         0.0     2481757.0  2.481757e+06   2.481757e+06  2.481757e+06
# mean          NaN           0.0  2.200646e+00   3.762064e+02  4.398509e-01
# std           NaN           0.0  3.542989e+01   1.653052e+05  1.743922e+01
# min           NaN           0.0  0.000000e+00   0.000000e+00  0.000000e+00
# 25%           NaN           0.0  1.000000e+00   7.000000e+01  0.000000e+00
# 50%           NaN           0.0  1.000000e+00   7.800000e+01  0.000000e+00
# 75%           NaN           0.0  3.000000e+00   1.950000e+02  1.000000e+00
# max           NaN           0.0  3.260400e+04   1.681047e+08  1.656600e+04
#
#        resp_ip_bytes  tunnel_parents  geo.orig.region  geo.orig.city  \
# count   2.481757e+06             0.0              0.0            0.0
# mean    1.119142e+02             NaN              NaN            NaN
# std     1.028589e+04             NaN              NaN            NaN
# min     0.000000e+00             NaN              NaN            NaN
# 25%     0.000000e+00             NaN              NaN            NaN
# 50%     0.000000e+00             NaN              NaN            NaN
# 75%     6.600000e+01             NaN              NaN            NaN
# max     2.753789e+06             NaN              NaN            NaN
#
#        geo.orig.latitude  geo.orig.longitude  geo.resp.latitude  \
# count              1.000               1.000       1.271348e+06
# mean              37.751             -97.822       3.777158e+01
# std                  NaN                 NaN       5.274103e-01
# min               37.751             -97.822       3.775100e+01
# 25%               37.751             -97.822       3.775100e+01
# 50%               37.751             -97.822       3.775100e+01
# 75%               37.751             -97.822       3.775100e+01
# max               37.751             -97.822       5.151640e+01
#
#        geo.resp.longitude
# count        1.271348e+06
# mean        -9.767794e+01
# std          3.730010e+00
# min         -1.233165e+02
# 25%         -9.782200e+01
# 50%         -9.782200e+01
# 75%         -9.782200e+01
# max         -9.300000e-02

# %%
df.head()
# Out:
#   _path                           ts                 uid  \
# 0  conn  2017-04-25T00:01:24.221943Z  CcRRUf4FvYVy0WM1tf
# 1  conn  2017-04-25T00:01:05.437399Z  CskjGr1swnXFezlM0b
# 2  conn  2017-04-25T00:01:05.435065Z   CAnrobD8Gp6TJUHkc
# 3  conn  2017-04-25T00:01:05.361443Z  CP4uAC4tn9VWjhJWu7
# 4  conn   2017-04-25T00:01:05.36117Z  CmQVh52Dk2zV5D9hgj
#
#                    id.orig_h  id.orig_p          id.resp_h  id.resp_p proto  \
# 0              192.168.50.15      49204      192.168.50.88         53   udp
# 1   fe80::d58e:a29a:c48:dd8f        135  ff02::1:ff98:c06b        136  icmp
# 2  fe80::2c51:b7cc:8a98:c06b        135  ff02::1:ff48:dd8f        136  icmp
# 3              192.168.50.18      51400        224.0.0.252       5355   udp
# 4   fe80::d58e:a29a:c48:dd8f      63788          ff02::1:3       5355   udp
#
#   service duration  ...  geo.orig.city  geo.orig.latitude geo.orig.longitude  \
# 0     dns    206us  ...            NaN                NaN                NaN
# 1     NaN      NaN  ...            NaN                NaN                NaN
# 2     NaN      NaN  ...            NaN                NaN                NaN
# 3     dns      NaN  ...            NaN                NaN                NaN
# 4     dns      NaN  ...            NaN                NaN                NaN
#
#    geo.resp.country_code  geo.resp.region  geo.resp.city geo.resp.latitude  \
# 0                    NaN              NaN            NaN               NaN
# 1                    NaN              NaN            NaN               NaN
# 2                    NaN              NaN            NaN               NaN
# 3                    NaN              NaN            NaN               NaN
# 4                    NaN              NaN            NaN               NaN
#
#    geo.resp.longitude                    community_id   label
# 0                 NaN  1:o9DmB+Xdg3mjcpAWPAa4xMSQ8PA=  Botnet
# 1                 NaN  1:/3BVcTgZBvIwH3NdRMIuCTKDsco=  Botnet
# 2                 NaN  1:4pI7NSr1zcExpnwgrplWKhUeX2Y=  Botnet
# 3                 NaN  1:qmfbUmATO8xesLDLONvCq/Hw0hs=  Botnet
# 4                 NaN  1:1O9I3C6IMbR1/6T8NUA+v6rvntU=  Botnet
#
# [5 rows x 34 columns]

# %%
df['ts'] = pd.to_datetime(df['ts'])

# %%
df['time'] = df['ts'].dt.strftime('%H:%M:%S')
df['date'] = df['ts'].dt.strftime('%Y-%m-%d')

# %%
df.insert(2, 'time', df.pop('time'))
df.insert(3, 'date', df.pop('date'))

# %%
df.head(2481757)
# Out:
#     _path                               ts      time        date  \
# 0    conn 2017-04-25 00:01:24.221943+00:00  00:01:24  2017-04-25
# 1    conn 2017-04-25 00:01:05.437399+00:00  00:01:05  2017-04-25
# 2    conn 2017-04-25 00:01:05.435065+00:00  00:01:05  2017-04-25
# 3    conn 2017-04-25 00:01:05.361443+00:00  00:01:05  2017-04-25
# 4    conn 2017-04-25 00:01:05.361170+00:00  00:01:05  2017-04-25
# ..    ...                              ...       ...         ...
# 294  conn 2017-06-13 01:57:40.657703+00:00  01:57:40  2017-06-13
# 295  conn 2017-06-13 01:57:40.283348+00:00  01:57:40  2017-06-13
# 296  conn 2017-06-13 01:57:39.365021+00:00  01:57:39  2017-06-13
# 297  conn 2017-06-13 01:57:39.364588+00:00  01:57:39  2017-06-13
# 298  conn 2017-06-13 01:57:38.658640+00:00  01:57:38  2017-06-13
#
#                     uid                  id.orig_h  id.orig_p  \
# 0    CcRRUf4FvYVy0WM1tf              192.168.50.15      49204
# 1    CskjGr1swnXFezlM0b   fe80::d58e:a29a:c48:dd8f        135
# 2     CAnrobD8Gp6TJUHkc  fe80::2c51:b7cc:8a98:c06b        135
# 3    CP4uAC4tn9VWjhJWu7              192.168.50.18      51400
# 4    CmQVh52Dk2zV5D9hgj   fe80::d58e:a29a:c48:dd8f      63788
# ..                  ...                        ...        ...
# 294   CWEiHh1SShNqzp0RK              192.168.50.51      59936
# 295  C4gcHS2lYNRehzDjGe              192.168.50.51      55221
# 296  CqvrX029jPSJJseFW4              192.168.50.88      51316
# 297  C5FyKT1tF02psaoWg9              192.168.50.19      60019
# 298  C1qVrt3a6cLOeBTxx2              192.168.50.51      61485
#
#              id.resp_h  id.resp_p proto  ... geo.orig.city geo.orig.latitude  \
# 0        192.168.50.88         53   udp  ...           NaN               NaN
# 1    ff02::1:ff98:c06b        136  icmp  ...           NaN               NaN
# 2    ff02::1:ff48:dd8f        136  icmp  ...           NaN               NaN
# 3          224.0.0.252       5355   udp  ...           NaN               NaN
# 4            ff02::1:3       5355   udp  ...           NaN               NaN
# ..                 ...        ...   ...  ...           ...               ...
# 294      192.168.50.88         53   udp  ...           NaN               NaN
# 295      192.168.50.88         53   udp  ...           NaN               NaN
# 296            8.8.4.4         53   udp  ...           NaN               NaN
# 297      192.168.50.88         53   udp  ...           NaN               NaN
# 298      192.168.50.88         53   udp  ...           NaN               NaN
#
#      geo.orig.longitude  geo.resp.country_code geo.resp.region  geo.resp.city  \
# 0                   NaN                    NaN             NaN            NaN
# 1                   NaN                    NaN             NaN            NaN
# 2                   NaN                    NaN             NaN            NaN
# 3                   NaN                    NaN             NaN            NaN
# 4                   NaN                    NaN             NaN            NaN
# ..                  ...                    ...             ...            ...
# 294                 NaN                    NaN             NaN            NaN
# 295                 NaN                    NaN             NaN            NaN
# 296                 NaN                     US             NaN            NaN
# 297                 NaN                    NaN             NaN            NaN
# 298                 NaN                    NaN             NaN            NaN
#
#      geo.resp.latitude  geo.resp.longitude                    community_id  \
# 0                  NaN                 NaN  1:o9DmB+Xdg3mjcpAWPAa4xMSQ8PA=
# 1                  NaN                 NaN  1:/3BVcTgZBvIwH3NdRMIuCTKDsco=
# 2                  NaN                 NaN  1:4pI7NSr1zcExpnwgrplWKhUeX2Y=
# 3                  NaN                 NaN  1:qmfbUmATO8xesLDLONvCq/Hw0hs=
# 4                  NaN                 NaN  1:1O9I3C6IMbR1/6T8NUA+v6rvntU=
# ..                 ...                 ...                             ...
# 294                NaN                 NaN  1:mxTfjGcQ4NKXLMjdY95cDBaTv90=
# 295                NaN                 NaN  1:YsCB+scJ8ppWcpZij0CAENJQ9ds=
# 296             37.751             -97.822  1:PNu0goJ1FjGRydc/UbZQU7z4izg=
# 297                NaN                 NaN  1:b041F23994Qmbo0E+76IpF7JCtw=
# 298                NaN                 NaN  1:wCKQp2nV3OJvKUWkJxYMV1y5Zmw=
#
#       label
# 0    Botnet
# 1    Botnet
# 2    Botnet
# 3    Botnet
# 4    Botnet
# ..      ...
# 294  Normal
# 295  Normal
# 296  Normal
# 297  Normal
# 298  Normal
#
# [2481757 rows x 36 columns]

# %%
df = df.sort_values(['date', 'time'], ascending=True)

# %%
df.head(2481757)
# Out:
#        _path                               ts      time        date  \
# 44657   conn 2017-04-19 02:54:16.972588+00:00  02:54:16  2017-04-19
# 44658   conn 2017-04-19 02:54:16.971992+00:00  02:54:16  2017-04-19
# 270428  conn 2017-04-19 02:54:16.972588+00:00  02:54:16  2017-04-19
# 270429  conn 2017-04-19 02:54:16.971992+00:00  02:54:16  2017-04-19
# 44655   conn 2017-04-19 02:54:19.193546+00:00  02:54:19  2017-04-19
# ...      ...                              ...       ...         ...
# 4       conn 2017-06-22 02:31:30.645201+00:00  02:31:30  2017-06-22
# 3       conn 2017-06-22 02:31:44.513718+00:00  02:31:44  2017-06-22
# 2       conn 2017-06-22 02:32:12.776697+00:00  02:32:12  2017-06-22
# 1       conn 2017-06-22 02:32:37.468717+00:00  02:32:37  2017-06-22
# 0       conn 2017-06-22 02:33:10.688579+00:00  02:33:10  2017-06-22
#
#                        uid                  id.orig_h  id.orig_p  \
# 44657    CxJk7F6UdwzSTe1Sk              192.168.50.11      58620
# 44658   CcjJ5P16TDfqrGeq3c  fe80::891f:ff8f:8660:beff      58618
# 270428  CfjRDf1MBW2erp4tyd              192.168.50.11      58620
# 270429  CjoXX82ODGPpqAYTRj  fe80::891f:ff8f:8660:beff      58618
# 44655    CAh3vw2cvv87Z0efx              192.168.50.14      55154
# ...                    ...                        ...        ...
# 4        Ca71arJpfnolxVaLf              192.168.50.60        138
# 3       CkcOml4Aww3gTnhGya              192.168.50.55        137
# 2       CyjMmB2D1shaHKn72g              192.168.50.57        137
# 1        Cht3HLL3Moraks302              192.168.50.51        137
# 0       CY0VMc1fQcoWR3QKw7              192.168.50.60        137
#
#               id.resp_h  id.resp_p proto  ... geo.orig.city geo.orig.latitude  \
# 44657   239.255.255.250       1900   udp  ...           NaN               NaN
# 44658           ff02::c       1900   udp  ...           NaN               NaN
# 270428  239.255.255.250       1900   udp  ...           NaN               NaN
# 270429          ff02::c       1900   udp  ...           NaN               NaN
# 44655   239.255.255.250       1900   udp  ...           NaN               NaN
# ...                 ...        ...   ...  ...           ...               ...
# 4        192.168.50.255        138   udp  ...           NaN               NaN
# 3        192.168.50.255        137   udp  ...           NaN               NaN
# 2        192.168.50.255        137   udp  ...           NaN               NaN
# 1        192.168.50.255        137   udp  ...           NaN               NaN
# 0        192.168.50.255        137   udp  ...           NaN               NaN
#
#         geo.orig.longitude  geo.resp.country_code geo.resp.region  \
# 44657                  NaN                    NaN             NaN
# 44658                  NaN                    NaN             NaN
# 270428                 NaN                    NaN             NaN
# 270429                 NaN                    NaN             NaN
# 44655                  NaN                    NaN             NaN
# ...                    ...                    ...             ...
# 4                      NaN                    NaN             NaN
# 3                      NaN                    NaN             NaN
# 2                      NaN                    NaN             NaN
# 1                      NaN                    NaN             NaN
# 0                      NaN                    NaN             NaN
#
#         geo.resp.city  geo.resp.latitude  geo.resp.longitude  \
# 44657             NaN                NaN                 NaN
# 44658             NaN                NaN                 NaN
# 270428            NaN                NaN                 NaN
# 270429            NaN                NaN                 NaN
# 44655             NaN                NaN                 NaN
# ...               ...                ...                 ...
# 4                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 0                 NaN                NaN                 NaN
#
#                           community_id   label
# 44657   1:69wLfIDkiwGxVaCOxbc9Zzkdj1g=  Botnet
# 44658   1:hXgaW+IATJ3548l0uRPdSY/NaYA=  Botnet
# 270428  1:69wLfIDkiwGxVaCOxbc9Zzkdj1g=  Botnet
# 270429  1:hXgaW+IATJ3548l0uRPdSY/NaYA=  Botnet
# 44655   1:o8LjmI2J3H3JSezvkWoV3LVa6xg=  Botnet
# ...                                ...     ...
# 4       1:L/9eqKhmc/yIjCbA/whb87dxmhg=  Normal
# 3       1:oenZbl3W2wbLPK4Bu5IfR9YhNoA=  Normal
# 2       1:JQX2G/xW3VgPHL3rw1MFNz+eTg8=  Normal
# 1       1:bDbXDEXMRBw5v0ieUEGUSeVPiDY=  Normal
# 0       1:UkroHSs8STF2pM8UdWxWR0R6OD8=  Normal
#
# [2481757 rows x 36 columns]

# %% [markdown]
# # Handling Missing Value

# %% [markdown]
# ## Check missing value

# %%
missing = pd.isnull(df).sum()
missing
# Out:
# _path                          0
# ts                             0
# time                           0
# date                           0
# uid                            0
# id.orig_h                      0
# id.orig_p                      0
# id.resp_h                      0
# id.resp_p                      0
# proto                          0
# service                   265435
# duration                 1178723
# orig_bytes               1178723
# resp_bytes               1178723
# conn_state                     0
# local_orig               2481757
# local_resp               2481757
# missed_bytes                   0
# history                    31835
# orig_pkts                      0
# orig_ip_bytes                  0
# resp_pkts                      0
# resp_ip_bytes                  0
# tunnel_parents           2481757
# geo.orig.country_code    2481756
# geo.orig.region          2481757
# geo.orig.city            2481757
# geo.orig.latitude        2481756
# geo.orig.longitude       2481756
# geo.resp.country_code    1210409
# geo.resp.region          2479768
# geo.resp.city            2479768
# geo.resp.latitude        1210409
# geo.resp.longitude       1210409
# community_id                   0
# label                          0
# dtype: int64

# %% [markdown]
# ## Function for Handling Missing Value

# %%
#Replace With Mean
def replace_missing_with_mean(df, columns):
    #Count mean in column
    mean_values = df[columns].mean()
    
    # Replace missing value with mean
    df[columns] = df[columns].fillna(mean_values)
    
    return df

#Replace With Median
def replace_missing_with_median(df, columns):
    #Get Median in column
    median_values = df[columns].median()
    
    # Replace missing value with median
    df[columns] = df[columns].fillna(median_values)
    
    return df

#Replace with Mode
def replace_missing_with_mode(df, columns):
    #Get Mode Value in Column
    mode_values = df[columns].mode().iloc[0]
    
    # Replace missing value with median
    df[columns] = df[columns].fillna(mode_values)
    
    return df

#Replace with 0 Value
def replace_missing_with_zero(df, columns):
    #Zero Value
    zero_value = 0
    
    # Replace missing value with median
    df[columns] = df[columns].fillna(zero_value)
    
    return df

def replace_missing_with_previous_row(df, column):

    df[column].fillna(method='ffill', inplace=True)
    
    return df

# %% [markdown]
# To use these functions, you need to provide two arguments:
#
# "df" - This is the Pandas DataFrame that you want to fill missing values in.
#
# "columns" - This is either a string or a list of strings that represents the name(s) of the column(s) in the DataFrame that you want to fill missing values in.

# %%
dftest = df
dftest = replace_missing_with_zero(dftest, 'service')

# %%
missing
# Out:
# _path                          0
# ts                             0
# time                           0
# date                           0
# uid                            0
# id.orig_h                      0
# id.orig_p                      0
# id.resp_h                      0
# id.resp_p                      0
# proto                          0
# service                   265435
# duration                 1178723
# orig_bytes               1178723
# resp_bytes               1178723
# conn_state                     0
# local_orig               2481757
# local_resp               2481757
# missed_bytes                   0
# history                    31835
# orig_pkts                      0
# orig_ip_bytes                  0
# resp_pkts                      0
# resp_ip_bytes                  0
# tunnel_parents           2481757
# geo.orig.country_code    2481756
# geo.orig.region          2481757
# geo.orig.city            2481757
# geo.orig.latitude        2481756
# geo.orig.longitude       2481756
# geo.resp.country_code    1210409
# geo.resp.region          2479768
# geo.resp.city            2479768
# geo.resp.latitude        1210409
# geo.resp.longitude       1210409
# community_id                   0
# label                          0
# dtype: int64

# %%
df = df.drop(['geo.orig.country_code','geo.orig.region','geo.orig.city',
              'geo.resp.latitude','geo.resp.longitude','geo.orig.latitude',
              'tunnel_parents','geo.orig.longitude','geo.resp.country_code',
              'geo.resp.region','geo.resp.city','local_orig','local_resp'], axis=1)

# %%
df = replace_missing_with_previous_row(df, 'service')
df = replace_missing_with_previous_row(df, 'orig_bytes')
df = replace_missing_with_previous_row(df, 'resp_bytes')
df = replace_missing_with_previous_row(df, 'history')

# %%
missing = pd.isnull(df).sum()
missing
# Out:
# _path                  0
# ts                     0
# time                   0
# date                   0
# uid                    0
# id.orig_h              0
# id.orig_p              0
# id.resp_h              0
# id.resp_p              0
# proto                  0
# service                0
# duration         1178723
# orig_bytes             0
# resp_bytes             0
# conn_state             0
# missed_bytes           0
# history                0
# orig_pkts              0
# orig_ip_bytes          0
# resp_pkts              0
# resp_ip_bytes          0
# community_id           0
# label                  0
# dtype: int64

# %% [markdown]
# # Variation Check

# %%
def check_column_variation(df, column_name):

    return set(df[column_name].unique())

# %% [markdown]
# HOW TO USE
#
# To use the "check_column_variation" function, you need to provide two arguments:
#
# "df" - This is the Pandas DataFrame that you want to check for unique values in a specific column.
#
# "column_name" - This is a string that represents the name of the column in the DataFrame that you want to check for unique values.

# %%
check_column_variation(dftest, 'service')
# Out:
# {0, 'dns', 'http', 'ntp', 'ssh'}

# %% [markdown]
# Duration

# %%
import pandas as pd

def process_time_string(time_string):
    time_unit = time_string[-2:]
    time_unit_s = time_string[-1:]
    time_value = time_string.replace('.', '')
    time_value_new = time_string.replace('.', '')
    time_value_new2 = time_string.replace('.', '')
    time_value_new3 = time_string.replace('.', '')
    if time_string.strip():
        if len(time_string) > 4:
            if time_string[1] == 'm':
                time_value = float(time_string[0]) * 60
                # time_value_new = time_value_new[2:]
                if time_unit == 'ms':
                    time_value_new = float(time_string[2:].replace('ms', '')) / 1000
                    time_total = time_value + time_value_new
                    return time_total
                elif time_unit == 'us':
                    time_value_new = float(time_string[2:].replace('us', '')) / 1000000
                    time_total = time_value + time_value_new
                    return time_total 
                elif time_unit_s == 's':
                    time_value_new = float(time_string[2:].replace('s', '')) 
                    time_total = time_value + time_value_new
                    return time_total
            elif time_string[2] == 'm':
                time_value = float(time_string[0]) * 60 * 10 + float(time_string[1]) * 60
                # time_value_new = time_string.replace('m', '')
                if time_unit == 'ms':
                    time_value_new = float(time_string[3:].replace('ms', '')) / 1000
                    time_total = time_value + time_value_new
                    return time_total
                elif time_unit == 'us':
                    time_value_new = float(time_string[3:].replace('us', '')) / 1000000
                    time_total = time_value + time_value_new
                    return time_total 
                elif time_unit_s == 's':
                    if time_string[3] == '':
                        time_value_new = float(time_string[4:].replace('s', ''))
                        time_total = time_value + time_value_new
                        return time_total
            elif time_string[1] == 'd':
                time_value = float(time_string[0]) * 86400
                if time_string[3] == 'h':
                    time_value_new = float(time_string[2]) * 3600
                    if time_string[5] == 'm':
                        time_value_new2 = float(time_string[4]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[6:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit == 'us':
                            time_value_new3 = float(time_string[6:].replace('us', '')) / 1000000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[6:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                    elif time_string[6] == 'm':
                        time_value_new2 = float(time_string[4]) * 60 * 10 + float(time_string[5]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[7:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                        elif time_unit == 'us':
                            time_value_new3 = float(time_string[7:].replace('us', '')) / 1000000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[7:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                elif time_string[4] == 'h':
                    time_value_new = float(time_string[2]) * 3600 * 10 + float(time_string[3]) * 3600
                    if time_string[6] == 'm':
                        time_value_new2 = float(time_string[5]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[7:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                        elif time_unit == 'us':
                            time_value_new3 = float(time_string[7:].replace('us', '')) / 1000000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[7:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                    elif time_string[7] == 'm':
                        time_value_new2 = float(time_string[5]) * 60 * 10 + float(time_string[6]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[8:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                        elif time_unit == 'us':
                            time_value_new3 = float(time_string[8:].replace('us', '')) / 1000000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[8:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
            elif time_string[2] == 'd':
                time_value = float(time_string[0]) * 86400 * 10 + float(time_string[1]) *86400
                if time_string[4] == 'h':
                    time_value_new = float(time_string[3]) * 3600
                    if time_string[6] == 'm':
                        time_value_new2 = float(time_string[5]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[7:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[7:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                    elif time_string[7] == 'm':
                        time_value_new2 = float(time_string[5]) * 60 * 10 + float(time_string[6]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[8:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[8:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                elif time_string[5] == 'h':
                    time_value_new = float(time_string[3]) * 3600 * 10 + float(time_string[4]) * 3600
                    if time_string[6] == 'm':
                        time_value_new2 = float(time_string[5]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[7:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[7:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
                    elif time_string[7] == 'm':
                        time_value_new2 = float(time_string[5]) * 60 * 10 + float(time_string[6]) * 60
                        if time_unit == 'ms':
                            time_value_new3 = float(time_string[7:].replace('ms', '')) / 1000
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total 
                        elif time_unit_s == 's':
                            time_value_new3 = float(time_string[7:].replace('s', '')) 
                            time_total = time_value + time_value_new + time_value_new2 + time_value_new3
                            return time_total
            elif time_unit == 'ms':
                time_value = float(time_string.replace('ms', '')) / 1000
                return time_value
            elif time_unit == 'us':
                time_value = float(time_string.replace('us', '')) / 1000000
                return time_value
            elif time_unit_s == 's':
                time_value = float(time_string.replace('s', ''))
                return time_value
            else:
                return None

df['duration'] = df['duration'].apply(lambda x: process_time_string(x) if isinstance(x, str) else x)

print(df['duration'])
# Out:
# 44657     5.996512
# 44658     5.996834
# 270428    5.996512
# 270429    5.996834
# 44655     5.996761
#             ...
# 4              NaN
# 3         1.486681
# 2         1.495538
# 1         1.487366
# 0         1.499129
# Name: duration, Length: 2481757, dtype: float64

# %%
df = replace_missing_with_previous_row(df, 'duration')

# %% [markdown]
# # Ekstraksi Fitur

# %%
df['PX'] = df['orig_pkts'] + df['resp_pkts']

df['NNP'] = np.where(df['orig_pkts'] + df['resp_pkts'] == 0, 1, 0)

df['NSP'] = ((63 >= df['orig_pkts'] + df['resp_pkts']) & (df['orig_pkts'] + df['resp_pkts'] <= 400)).astype(int)

df['PSP'] = df['NSP'] / df['PX'] 

df['IOPR'] = df['orig_pkts'] + df['resp_pkts']

df['reconnection'] = np.where(df['history'].str.contains('Sr%'), 1, 0)
df['reconnection'] = df['reconnection'].fillna(0).astype(int)

df['FPS'] = df['orig_ip_bytes'] / df['orig_pkts']
df['FPS'] = df['FPS'].fillna(0)

df['TBT'] = df['orig_ip_bytes'] + df['resp_ip_bytes']

df['APL'] = (df['orig_ip_bytes'] + df['resp_ip_bytes']) / df['PX']

df['BS'] = ((df['orig_ip_bytes']+ df['resp_ip_bytes'])* 8 ) / df['duration']

df['PS'] =(df['orig_pkts'] + df['resp_pkts']) / df['duration'] 

df['PPS'] = (df['orig_pkts'] + df['resp_pkts']) / df['duration']

# %% [markdown]
# # Normalisasi Data

# %% [markdown]
# *Normalisasi*

# %%
dff = df

# %%
label = df.pop('label') 
df.insert(len(df.columns), 'label', label)

# %%
y = df['label']

# %%
# Normalisasi
sc = MinMaxScaler(feature_range=(0, 1))

# Apply the Min-Max Scaler to the numerical columns
df = pd.DataFrame(data=sc.fit_transform(df.select_dtypes(include=['float64', 'int64'])), columns=df.select_dtypes(include=['float64', 'int64']).columns)

# %% [markdown]
# # Train & Test Split Stratify

# %%
from sklearn.model_selection import train_test_split

# %%
X = df
X.head()
# Out:
#    id.orig_p  id.resp_p  duration  orig_bytes  resp_bytes  missed_bytes  \
# 0   0.894479   0.108571  0.000006    0.000004         0.0           0.0
# 1   0.894449   0.108571  0.000006    0.000004         0.0           0.0
# 2   0.894479   0.108571  0.000006    0.000004         0.0           0.0
# 3   0.894449   0.108571  0.000006    0.000004         0.0           0.0
# 4   0.841589   0.108571  0.000006    0.000004         0.0           0.0
#
#    orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes        PX       PSP  \
# 0   0.000184       0.000005        0.0            0.0  0.000153  0.166667
# 1   0.000184       0.000006        0.0            0.0  0.000153  0.166667
# 2   0.000184       0.000005        0.0            0.0  0.000153  0.166667
# 3   0.000184       0.000006        0.0            0.0  0.000153  0.166667
# 4   0.000184       0.000005        0.0            0.0  0.000153  0.166667
#
#        IOPR       FPS       TBT       APL        BS        PS       PPS
# 0  0.000153  0.006772  0.000005  0.007219  0.000012  0.000016  0.000016
# 1  0.000153  0.007395  0.000006  0.008163  0.000013  0.000016  0.000016
# 2  0.000153  0.006772  0.000005  0.007219  0.000012  0.000016  0.000016
# 3  0.000153  0.007395  0.000006  0.008163  0.000013  0.000016  0.000016
# 4  0.000153  0.006772  0.000005  0.007219  0.000012  0.000016  0.000016

# %%
y.value_counts()
# Out:
# Botnet    2371184
# Normal     110573
# Name: label, dtype: int64

# %% [markdown]
# ## Use entire data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
# Menghitung jumlah kelas pada train set dan test set
train_class_counts = y_train.value_counts()
test_class_counts = y_test.value_counts()

# Menampilkan hasil
print("Jumlah kelas pada train set:")
print(train_class_counts)

print("\nJumlah kelas pada test set:")
print(test_class_counts)
# Out:
# Jumlah kelas pada train set:
# Botnet    1896947
# Normal      88458
# Name: label, dtype: int64
#
# Jumlah kelas pada test set:
# Botnet    474237
# Normal     22115
# Name: label, dtype: int64

# %% [markdown]
# ## Use Balance Data

# %%
# Memotong jumlah data botnet agar sama dengan jumlah data normal
botnet_count = (dff['label'] == 'Botnet').sum()
normal_count = (dff['label'] == 'Normal').sum()

if botnet_count > normal_count:
    data1 = pd.concat([dff[dff['label'] == 'Botnet'].head(normal_count), dff[dff['label'] == 'Normal']])
else:
    data1 = pd.concat([dff[dff['label'] == 'Botnet'], dff[dff['label'] == 'Normal'].head(botnet_count)])

# Menampilkan jumlah data di setiap kategori setelah dipotong
print(data1['label'].value_counts())
# Out:
# Botnet    110573
# Normal    110573
# Name: label, dtype: int64

# %%
data1.head()
# Out:
#        _path                               ts      time        date  \
# 44657   conn 2017-04-19 02:54:16.972588+00:00  02:54:16  2017-04-19
# 44658   conn 2017-04-19 02:54:16.971992+00:00  02:54:16  2017-04-19
# 270428  conn 2017-04-19 02:54:16.972588+00:00  02:54:16  2017-04-19
# 270429  conn 2017-04-19 02:54:16.971992+00:00  02:54:16  2017-04-19
# 44655   conn 2017-04-19 02:54:19.193546+00:00  02:54:19  2017-04-19
#
#                        uid                  id.orig_h  id.orig_p  \
# 44657    CxJk7F6UdwzSTe1Sk              192.168.50.11      58620
# 44658   CcjJ5P16TDfqrGeq3c  fe80::891f:ff8f:8660:beff      58618
# 270428  CfjRDf1MBW2erp4tyd              192.168.50.11      58620
# 270429  CjoXX82ODGPpqAYTRj  fe80::891f:ff8f:8660:beff      58618
# 44655    CAh3vw2cvv87Z0efx              192.168.50.14      55154
#
#               id.resp_h  id.resp_p proto  ...       PSP  IOPR  reconnection  \
# 44657   239.255.255.250       1900   udp  ...  0.166667     6             0
# 44658           ff02::c       1900   udp  ...  0.166667     6             0
# 270428  239.255.255.250       1900   udp  ...  0.166667     6             0
# 270429          ff02::c       1900   udp  ...  0.166667     6             0
# 44655   239.255.255.250       1900   udp  ...  0.166667     6             0
#
#           FPS  TBT    APL           BS        PS       PPS   label
# 44657   152.0  912  152.0  1216.707313  1.000582  1.000582  Botnet
# 44658   166.0  996  166.0  1328.701111  1.000528  1.000528  Botnet
# 270428  152.0  912  152.0  1216.707313  1.000582  1.000582  Botnet
# 270429  166.0  996  166.0  1328.701111  1.000528  1.000528  Botnet
# 44655   152.0  912  152.0  1216.656792  1.000540  1.000540  Botnet
#
# [5 rows x 35 columns]

# %%
y1 = data1['label']

# %%
# Normalisasi
scc = MinMaxScaler(feature_range=(0, 1))

# Apply the Min-Max Scaler to the numerical columns
data1 = pd.DataFrame(data=scc.fit_transform(data1.select_dtypes(include=['float64', 'int64'])), columns=data1.select_dtypes(include=['float64', 'int64']).columns)

# %%
X1 = data1
X1.head()
# Out:
#    id.orig_p  id.resp_p  duration  orig_bytes  resp_bytes  missed_bytes  \
# 0   0.894479   0.108571  0.000011    0.000004         0.0           0.0
# 1   0.894449   0.108571  0.000011    0.000004         0.0           0.0
# 2   0.894479   0.108571  0.000011    0.000004         0.0           0.0
# 3   0.894449   0.108571  0.000011    0.000004         0.0           0.0
# 4   0.841589   0.108571  0.000011    0.000004         0.0           0.0
#
#    orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes        PX       PSP  \
# 0   0.000334       0.000005        0.0            0.0  0.000187  0.166667
# 1   0.000334       0.000006        0.0            0.0  0.000187  0.166667
# 2   0.000334       0.000005        0.0            0.0  0.000187  0.166667
# 3   0.000334       0.000006        0.0            0.0  0.000187  0.166667
# 4   0.000334       0.000005        0.0            0.0  0.000187  0.166667
#
#        IOPR       FPS       TBT       APL        BS       PS      PPS
# 0  0.000187  0.006772  0.000005  0.007219  0.000012  0.00005  0.00005
# 1  0.000187  0.007395  0.000006  0.008163  0.000013  0.00005  0.00005
# 2  0.000187  0.006772  0.000005  0.007219  0.000012  0.00005  0.00005
# 3  0.000187  0.007395  0.000006  0.008163  0.000013  0.00005  0.00005
# 4  0.000187  0.006772  0.000005  0.007219  0.000012  0.00005  0.00005

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, stratify=y1)

# %%
# Menghitung jumlah kelas pada train set dan test set
train_class_counts1 = y_train1.value_counts()
test_class_counts1 = y_test1.value_counts()

# Menampilkan hasil
print("Jumlah kelas pada train set:")
print(train_class_counts1)

print("\nJumlah kelas pada test set:")
print(test_class_counts1)
# Out:
# Jumlah kelas pada train set:
# Normal    88458
# Botnet    88458
# Name: label, dtype: int64
#
# Jumlah kelas pada test set:
# Normal    22115
# Botnet    22115
# Name: label, dtype: int64

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from sklearn.tree import export_text

# %% [markdown]
# ### Decision Tree Entire Data

# %%
# Decision Tree classifer object
clf = DecisionTreeClassifier(max_depth = None, min_samples_split = 2)

# Train Decision Tree
clf = clf.fit(X_train,y_train)

#Predict
y_pred = clf.predict(X_test)

# hasil
score = metrics.accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(score)
print(report)
# Out:
# 0.9835298336664303
#               precision    recall  f1-score   support
#
#       Botnet       0.99      1.00      0.99    474237
#       Normal       0.88      0.73      0.80     22115
#
#     accuracy                           0.98    496352
#    macro avg       0.94      0.86      0.89    496352
# weighted avg       0.98      0.98      0.98    496352

# %%
r = export_text(clf, feature_names=df.columns.to_list())
print(r)
# Out:
# |--- APL <= 0.00
# |   |--- id.resp_p <= 0.00
# |   |   |--- PPS <= 0.00
# |   |   |   |--- duration <= 0.00
# |   |   |   |   |--- PSP <= 0.06
# |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- PSP >  0.06
# |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |--- duration >  0.00
# |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |--- class: Normal
# |   |   |--- PPS >  0.00
# |   |   |   |--- PPS <= 0.00
# |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |--- PPS >  0.00
# |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |--- TBT <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- TBT >  0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |--- IOPR <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- IOPR >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- orig_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PX >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- orig_pkts <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- orig_pkts >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 30
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- orig_pkts <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- orig_pkts >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |--- PS <= 0.07
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PS >  0.07
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |--- id.resp_p >  0.00
# |   |   |--- FPS <= 0.00
# |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |--- id.resp_p <= 0.00
# |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |--- orig_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 25
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- orig_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- id.resp_p >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |--- id.orig_p <= 0.75
# |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- id.orig_p >  0.75
# |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- id.resp_p >  0.00
# |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |--- id.orig_p <= 0.04
# |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- id.resp_p >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- id.orig_p >  0.04
# |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.31
# |   |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- id.resp_p >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- id.resp_p >  0.31
# |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 70
# |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- id.orig_p >  0.00
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 44
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 32
# |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 34
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |--- id.resp_p <= 0.01
# |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- id.resp_p >  0.01
# |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |--- PS <= 0.05
# |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- PS >  0.05
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.73
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.73
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |--- orig_pkts <= 0.00
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- orig_pkts >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.75
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.75
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |   |--- id.resp_p >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 31
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 25
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 33
# |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PS >  0.01
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |--- FPS >  0.00
# |   |   |   |--- id.resp_p <= 0.00
# |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |--- class: Normal
# |   |   |   |--- id.resp_p >  0.00
# |   |   |   |   |--- APL <= 0.00
# |   |   |   |   |   |--- PSP <= 0.15
# |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- PSP >  0.15
# |   |   |   |   |   |   |--- IOPR <= 0.00
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- IOPR >  0.00
# |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- APL >  0.00
# |   |   |   |   |   |--- PS <= 0.01
# |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# ...
# |   |   |   |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- APL <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- resp_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- FPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- FPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- FPS >  0.01
# |   |   |   |   |   |   |--- APL <= 0.01
# |   |   |   |   |   |   |   |--- TBT <= 0.00
# |   |   |   |   |   |   |   |   |--- PX <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PX >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- TBT >  0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |--- FPS >  0.01
# |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |--- class: Normal
# |   |--- FPS >  0.01
# |   |   |--- APL <= 0.01
# |   |   |   |--- id.orig_p <= 0.93
# |   |   |   |   |--- id.orig_p <= 0.84
# |   |   |   |   |   |--- id.orig_p <= 0.76
# |   |   |   |   |   |   |--- id.orig_p <= 0.75
# |   |   |   |   |   |   |   |--- APL <= 0.01
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |   |--- APL <= 0.01
# |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |   |   |--- id.resp_p <= 0.65
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- id.orig_p >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- id.resp_p >  0.65
# |   |   |   |   |   |   |   |   |   |   |--- orig_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- orig_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- id.orig_p >  0.75
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- id.orig_p >  0.76
# |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |--- id.orig_p >  0.84
# |   |   |   |   |   |--- id.orig_p <= 0.89
# |   |   |   |   |   |   |--- id.resp_p <= 0.06
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- id.resp_p >  0.06
# |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- id.orig_p >  0.89
# |   |   |   |   |   |   |--- id.orig_p <= 0.92
# |   |   |   |   |   |   |   |--- id.orig_p <= 0.91
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- id.orig_p >  0.91
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- id.orig_p >  0.92
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |--- id.orig_p >  0.93
# |   |   |   |   |--- id.orig_p <= 0.97
# |   |   |   |   |   |--- class: Normal
# |   |   |   |   |--- id.orig_p >  0.97
# |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |--- class: Botnet
# |   |   |--- APL >  0.01
# |   |   |   |--- FPS <= 0.01
# |   |   |   |   |--- class: Normal
# |   |   |   |--- FPS >  0.01
# |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |--- FPS <= 0.01
# |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- BS >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- FPS >  0.01
# |   |   |   |   |   |   |   |--- orig_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- orig_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |--- PS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- BS >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- BS <= 0.04
# |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- BS >  0.04
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- resp_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |--- FPS <= 0.01
# |   |   |   |   |   |   |--- APL <= 0.01
# |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- APL >  0.01
# |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- PPS <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- PPS >  0.00
# |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |--- FPS >  0.01
# |   |   |   |   |   |   |--- id.orig_p <= 0.79
# |   |   |   |   |   |   |   |--- FPS <= 0.01
# |   |   |   |   |   |   |   |   |--- BS <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |   |--- BS >  0.00
# |   |   |   |   |   |   |   |   |   |--- orig_bytes <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- orig_bytes >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |   |--- FPS >  0.01
# |   |   |   |   |   |   |   |   |--- duration <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |   |--- duration >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: Botnet
# |   |   |   |   |   |   |--- id.orig_p >  0.79
# |   |   |   |   |   |   |   |--- orig_ip_bytes <= 0.00
# |   |   |   |   |   |   |   |   |--- class: Normal
# |   |   |   |   |   |   |   |--- orig_ip_bytes >  0.00
# |   |   |   |   |   |   |   |   |--- class: Botnet

# %% [markdown]
# ### K-Fold Decision Tree Entire Data

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.983 (0.000)

# %% [markdown]
# ### Decision Tree Balanced Data

# %%
# Decision Tree classifer object
clf1 = DecisionTreeClassifier(max_depth = None, min_samples_split = 2)

# Train Decision Tree
clf1 = clf1.fit(X_train1,y_train1)

#Predict
y_pred1 = clf.predict(X_test1)

# hasil
score = metrics.accuracy_score(y_test1, y_pred1)
report = classification_report(y_test1, y_pred1)
print(score)
print(report)
# Out:
# 0.779787474564775
#               precision    recall  f1-score   support
#
#       Botnet       0.76      0.81      0.79     22115
#       Normal       0.80      0.75      0.77     22115
#
#     accuracy                           0.78     44230
#    macro avg       0.78      0.78      0.78     44230
# weighted avg       0.78      0.78      0.78     44230

# %% [markdown]
# ### K-Fold Decision Tree Entire Data

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.983 (0.000)
